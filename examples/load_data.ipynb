# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://user:password@localhost:3307/orders_db"
)

df = pd.read_csv("inventory_data.csv")

df.to_sql("inventory", engine, if_exists="append", index=False)
# Out:
# 10
